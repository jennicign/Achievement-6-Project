# %% [markdown]
# # Data Preparation - Cleaning, Wrangling, Deriving Variables, Merging, Integration

# %% [markdown]
# ### Contents:

# %% [markdown]
# 1. Importing Libraries and Data
# 2. Cleaning and Wrangling Hospital Readmissions Reductions Program Dataset
#    - Deriving New Variables - Hospital Readmissions Reductions Program Dataset
# 3. Cleaning and Wrangling Hospital General Information Dataset
# 4. Cleaning and Wrangling HVBP Clinical Outcomes Dataset
#    - Deriving New Variables - HVBP Clinical Outcomes Dataset
# 5. Data Merging
# 6. Consistency Checks on Integreated Dataset
# 7. Exporting

# %% [markdown]
# # 01. Importing Libraries and Data

# %%
# Import libraries

import os
import pandas as pd
import numpy as np

# %%
# Create path

path = r'C:\Users\jenci\Documents\Data Analytics\Data Analytics\Advanced Analytics and Dashboard Design\Acheivement 6'

# %%
# Import dataframes

df_hrrp = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'hospital_readmissions_reduction_program.csv'), index_col=False)
df_hgi = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'hospital_general_information.csv'), index_col=False)
df_hvbp = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'hvbp_clinical_outcomes.csv'), index_col=False)

# %% [markdown]
# # 02. Cleaning and Wrangling Hospital Readmisssions Reductions Program Dataset

# %%
# Check shape

df_hrrp.shape
# Out:
# (18774, 12)

# %%
# Check dataframe

df_hrrp.head(5)
# Out:
#                      Facility Name  Facility ID State            Measure Name  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL  READM-30-HIP-KNEE-HRRP
# 1  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL        READM-30-HF-HRRP
# 2  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL       READM-30-AMI-HRRP
# 3  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL        READM-30-PN-HRRP
# 4  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL      READM-30-CABG-HRRP
#
#    Number of Discharges  Footnote  Excess Readmission Ratio  \
# 0                   NaN       NaN                    0.8916
# 1                 616.0       NaN                    1.1003
# 2                 274.0       NaN                    0.9332
# 3                 404.0       NaN                    0.9871
# 4                 126.0       NaN                    0.9517
#
#    Predicted Readmission Rate  Expected Readmission Rate  \
# 0                      3.5325                     3.9618
# 1                     23.1263                    21.0184
# 2                     12.9044                    13.8283
# 3                     17.0529                    17.2762
# 4                      9.8131                    10.3112
#
#   Number of Readmissions  Start Date    End Date
# 0      Too Few to Report  07/01/2019  06/30/2022
# 1                    149  07/01/2019  06/30/2022
# 2                     32  07/01/2019  06/30/2022
# 3                     68  07/01/2019  06/30/2022
# 4                     11  07/01/2019  06/30/2022

# %% [markdown]
# > **Addressing Duplicates:**
# >
# > During the data profiling phase, **verified the absence of duplicates.**

# %%
# Remove all rows that have Nulls in 'Predicted Readmissions Ratio' column and any values in the Footnote column

df_hrrp_copy = df_hrrp[df_hrrp['Predicted Readmission Rate'].notna()]

# %% [markdown]
# > Removing missing rows in the **'Predicted Readmission Rate'** column is based on the criterion that all subsequent quantitative variables related to it are also missing. These values are missing completely at random, primarily because hospitals did not participate in data submission despite being listed.

# %%
# Check output 
df_hrrp_copy['Predicted Readmission Rate'].isnull().sum()
# Out:
# 0

# %% [markdown]
# > A sum of zero means all of the rows with missing data in **'Predicted Readmission Rate'** were removed.

# %%
# Check output

df_hrrp_copy.shape
# Out:
# (12077, 12)

# %%
# Remove 'Footnote' 'Start Date' 'End Date' 'Number of Discharges' 'Number of Readmissions; columns

df_hrrp_copy = df_hrrp_copy.drop(['Footnote', 'Start Date', 'End Date', 'Number of Discharges', 'Number of Readmissions'], axis=1)

# %% [markdown]
# > The decision is to remove **'Number of Discharges'** and **'Number of Readmissions'** from the dataset.
# >
# > These columns contain a significant amount of missing data because the values were suppressed to protect patient privacy. Despite their importance as measurements, the data is incomplete due to this suppression.
# >
# > By removing 'Number of Discharges' and 'Number of Readmissions', focus can be directed towards analyzing more complete and relevant data points, ensuring the analysis remains robust and actionable.
# >
# > Reasons for Dropping the Columns:
# >
# > 1. **Data Completeness**: Both 'Number of Discharges' and 'Number of Readmissions' have substantial missing values, which can impact the reliability and comprehensiveness of the analysis.
# >
# > 2. **Alternative Measures**: Fortunately, access remains available to other valuable metrics such as ratios and rates, which provide meaningful insights into hospital performance without compromising patient privacy.
# >
# > 3. **Reason for Missing Data**: The missing values in these columns are not due to a systematic issue but rather because hospitals chose not to participate in data submission for various reasons. This missingness can be considered at random and unrelated to specific hospital characteristics.

# %%
# Check output

df_hrrp_copy.head(1)
# Out:
#                      Facility Name  Facility ID State            Measure Name  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL  READM-30-HIP-KNEE-HRRP
#
#    Excess Readmission Ratio  Predicted Readmission Rate  \
# 0                    0.8916                      3.5325
#
#    Expected Readmission Rate
# 0                     3.9618

# %%
# Rename 'Predeicted Readmission Rate' to 'Observed Readmission Rate' -- Renaming this to clarify for general audiences

df_hrrp_copy.rename(columns={'Predicted Readmission Rate': 'Observed Readmission Rate'}, inplace=True)

# %%
# Check datatypes

df_hrrp_copy.dtypes
# Out:
# Facility Name                 object
# Facility ID                    int64
# State                         object
# Measure Name                  object
# Excess Readmission Ratio     float64
# Observed Readmission Rate    float64
# Expected Readmission Rate    float64
# dtype: object

# %%
# Check for mixed data types

for col in df_hrrp_copy.columns.tolist():
    weird = (df_hrrp_copy[[col]].map(type) != df_hrrp_copy[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df_hrrp_copy[weird]) > 0:
        print (col)

# %% [markdown]
# > Lack of output means there are **no mixed data types present in df_hrrp_copy.**

# %%
# Check for missing values

df_hrrp_copy.isnull().sum()
# Out:
# Facility Name                0
# Facility ID                  0
# State                        0
# Measure Name                 0
# Excess Readmission Ratio     0
# Observed Readmission Rate    0
# Expected Readmission Rate    0
# dtype: int64

# %%
# Check shape

df_hrrp_copy.shape
# Out:
# (12077, 7)

# %% [markdown]
# ## 02a. Deriving New Variables - Hospital Readmissions Reductions Program Dataset

# %%
# Define threhold for new flag
threshold_1 = 1.0

# Derive new variable called 'Excess Readmission Flag' 
df_hrrp_copy['Excess Readmissions Threshold'] = df_hrrp_copy['Excess Readmission Ratio'].apply(lambda x: 'Above Threshold' if x > threshold_1 else 'Below Threshold')

# %%
# Check output

df_hrrp_copy.head(1)
# Out:
#                      Facility Name  Facility ID State            Measure Name  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL  READM-30-HIP-KNEE-HRRP
#
#    Excess Readmission Ratio  Observed Readmission Rate  \
# 0                    0.8916                     3.5325
#
#    Expected Readmission Rate Excess Readmissions Threshold
# 0                     3.9618               Below Threshold

# %%
# Check shape of cleaned and wrangled df_hrrp_copy dataframe

df_hrrp_copy.shape
# Out:
# (12077, 8)

# %% [markdown]
# # 03. Cleaning and Wrangling Hospital General Information Dataset

# %%
# Check shape

df_hgi.shape
# Out:
# (5425, 39)

# %%
# Check dataframe

pd.set_option('display.max_columns', None) # Set option to view all columns
df_hgi.head(5)
# Out:
#   Facility ID                    Facility Name                     Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 2      010006     NORTH ALABAMA MEDICAL CENTER         1701 VETERANS DRIVE
# 3      010007         MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4      010008      CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 1      BOAZ    AL     35957      MARSHALL   (256) 593-8310
# 2  FLORENCE    AL     35630    LAUDERDALE   (256) 629-1000
# 3       OPP    AL     36467     COVINGTON   (334) 493-3541
# 4   LUVERNE    AL     36049      CRENSHAW   (334) 335-3374
#
#           Hospital Type                           Hospital Ownership  \
# 0  Acute Care Hospitals  Government - Hospital District or Authority
# 1  Acute Care Hospitals  Government - Hospital District or Authority
# 2  Acute Care Hospitals                                  Proprietary
# 3  Acute Care Hospitals               Voluntary non-profit - Private
# 4  Acute Care Hospitals                                  Proprietary
#
#   Emergency Services Meets criteria for promoting interoperability of EHRs  \
# 0                Yes                                                  Y
# 1                Yes                                                  Y
# 2                Yes                                                  Y
# 3                Yes                                                  Y
# 4                Yes                                                  Y
#
#   Meets criteria for birthing friendly designation Hospital overall rating  \
# 0                                                Y                       3
# 1                                              NaN                       2
# 2                                                Y                       1
# 3                                              NaN                       2
# 4                                              NaN           Not Available
#
#    Hospital overall rating footnote MORT Group Measure Count  \
# 0                               NaN                        7
# 1                               NaN                        7
# 2                               NaN                        7
# 3                               NaN                        7
# 4                              16.0                        7
#
#   Count of Facility MORT Measures Count of MORT Measures Better  \
# 0                               7                             1
# 1                               6                             0
# 2                               7                             0
# 3                               3                             0
# 4                               1                             0
#
#   Count of MORT Measures No Different Count of MORT Measures Worse  \
# 0                                   5                            1
# 1                                   4                            2
# 2                                   5                            2
# 3                                   3                            0
# 4                                   1                            0
#
#    MORT Group Footnote Safety Group Measure Count  \
# 0                  NaN                          8
# 1                  NaN                          8
# 2                  NaN                          8
# 3                  NaN                          8
# 4                  NaN                          8
#
#   Count of Facility Safety Measures Count of Safety Measures Better  \
# 0                                 8                               2
# 1                                 7                               0
# 2                                 7                               2
# 3                                 2                               0
# 4                     Not Available                   Not Available
#
#   Count of Safety Measures No Different Count of Safety Measures Worse  \
# 0                                     6                              0
# 1                                     6                              1
# 2                                     5                              0
# 3                                     2                              0
# 4                         Not Available                  Not Available
#
#    Safety Group Footnote READM Group Measure Count  \
# 0                    NaN                        11
# 1                    NaN                        11
# 2                    NaN                        11
# 3                    NaN                        11
# 4                    5.0                        11
#
#   Count of Facility READM Measures Count of READM Measures Better  \
# 0                               11                              0
# 1                               10                              0
# 2                                9                              0
# 3                                6                              0
# 4                                2                              0
#
#   Count of READM Measures No Different Count of READM Measures Worse  \
# 0                                   10                             1
# 1                                   10                             0
# 2                                    7                             2
# 3                                    5                             1
# 4                                    2                             0
#
#    READM Group Footnote Pt Exp Group Measure Count  \
# 0                   NaN                          8
# 1                   NaN                          8
# 2                   NaN                          8
# 3                   NaN                          8
# 4                   NaN                          8
#
#   Count of Facility Pt Exp Measures  Pt Exp Group Footnote  \
# 0                                 8                    NaN
# 1                                 8                    NaN
# 2                                 8                    NaN
# 3                                 8                    NaN
# 4                     Not Available                    5.0
#
#   TE Group Measure Count Count of Facility TE Measures  TE Group Footnote
# 0                     12                            10                NaN
# 1                     12                            11                NaN
# 2                     12                            11                NaN
# 3                     12                             7                NaN
# 4                     12                             6                NaN

# %% [markdown]
# > **Addressing Duplicates:**
# >
# > During the data profiling phase, **verified the absence of duplicates.**

# %%
# Create copy of Hospital General Information dataframe
df_hgi_copy = df_hgi.copy()

# Create list of columns to remove
columns_to_remove_1 = [
    'Facility ID',
    'Hospital overall rating footnote',
    'MORT Group Measure Count',
    'Count of MORT Measures No Different',
    'MORT Group Footnote',
    'Safety Group Measure Count',
    'Count of Safety Measures No Different',
    'Safety Group Footnote',
    'READM Group Measure Count',
    'Count of READM Measures No Different',
    'READM Group Footnote',
    'Pt Exp Group Measure Count',
    'Pt Exp Group Footnote',
    'TE Group Measure Count',
    'Count of Facility Pt Exp Measures',
    'Count of Facility TE Measures',
    'TE Group Footnote'
]

# Remove list of columns from df_hgi_copy
df_hgi_copy = df_hgi_copy.drop(columns=columns_to_remove_1)

# %% [markdown]
# > **Opt to exclude 'Facility ID'** due to its differing data type, which complicates merging and isn't essential enough to justify the effort required for alignment, as there are several additional keys available for merging.

# %%
# Remove all rows that contain 'Not Avaialable' in 'Hospital Rating' columns

df_hgi_copy = df_hgi_copy[~df_hgi_copy['Hospital overall rating'].astype(str).str.contains('Not Available')]

# %% [markdown]
# > **Deleting rows with 'Not Available' entries in the 'Hospital overall rating' column is justified because** this variable stands out due to **its** unconnected nature from other variables of interest in our dataset, such as readmission rates and hospital characteristics. This **lack of interdependence ensures  that removing these rows does not compromise the integrity or interconnectedness of our analysis.**
# >
# > Additionally, the missing values in the 'Hospital overall rating' column are random and stem from various factors including CMS data standardization, insufficient rating counts, non-submission by hospitals, and discrepancies between submitted and CMS data. This randomness makes imputation less reliable and introduces potential biases. **Despite losing approximately 43% of the original data, this approach strengthens the validity of our analysis, allowing for a more focused evaluation of hospital performance characteristics.**

# %%
# Check shape

df_hgi_copy.shape
# Out:
# (3042, 22)

# %%
# Check for remaining null values

df_hgi_copy.eq('Not Available').sum()
# Out:
# Facility Name                                             0
# Address                                                   0
# City/Town                                                 0
# State                                                     0
# ZIP Code                                                  0
# County/Parish                                             0
# Telephone Number                                          0
# Hospital Type                                             0
# Hospital Ownership                                        0
# Emergency Services                                        0
# Meets criteria for promoting interoperability of EHRs     0
# Meets criteria for birthing friendly designation          0
# Hospital overall rating                                   0
# Count of Facility MORT Measures                          65
# Count of MORT Measures Better                            65
# Count of MORT Measures Worse                             65
# Count of Facility Safety Measures                        79
# Count of Safety Measures Better                          79
# Count of Safety Measures Worse                           79
# Count of Facility READM Measures                          1
# Count of READM Measures Better                            1
# Count of READM Measures Worse                             1
# dtype: int64

# %%
# Check datatypes of each columns -- In preparation to calculate mean as we need values to be numeric

df_hgi_copy.dtypes
# Out:
# Facility Name                                            object
# Address                                                  object
# City/Town                                                object
# State                                                    object
# ZIP Code                                                  int64
# County/Parish                                            object
# Telephone Number                                         object
# Hospital Type                                            object
# Hospital Ownership                                       object
# Emergency Services                                       object
# Meets criteria for promoting interoperability of EHRs    object
# Meets criteria for birthing friendly designation         object
# Hospital overall rating                                  object
# Count of Facility MORT Measures                          object
# Count of MORT Measures Better                            object
# Count of MORT Measures Worse                             object
# Count of Facility Safety Measures                        object
# Count of Safety Measures Better                          object
# Count of Safety Measures Worse                           object
# Count of Facility READM Measures                         object
# Count of READM Measures Better                           object
# Count of READM Measures Worse                            object
# dtype: object

# %%
# Create list of columns in df_hgi_copy for which we need to change datatypes
columns_to_convert_2 = [
    'Count of Facility MORT Measures',
    'Count of MORT Measures Better',
    'Count of MORT Measures Worse',
    'Count of Facility Safety Measures',
    'Count of Safety Measures Better',
    'Count of Safety Measures Worse',
    'Count of Facility READM Measures',
    'Count of READM Measures Better',
    'Count of READM Measures Worse',
]

# Change datatypes to numeric
df_hgi_copy[columns_to_convert_2] = df_hgi_copy[columns_to_convert_2].apply(pd.to_numeric, errors='coerce').astype('float64')

# %%
# Check output

df_hgi_copy.dtypes
# Out:
# Facility Name                                             object
# Address                                                   object
# City/Town                                                 object
# State                                                     object
# ZIP Code                                                   int64
# County/Parish                                             object
# Telephone Number                                          object
# Hospital Type                                             object
# Hospital Ownership                                        object
# Emergency Services                                        object
# Meets criteria for promoting interoperability of EHRs     object
# Meets criteria for birthing friendly designation          object
# Hospital overall rating                                   object
# Count of Facility MORT Measures                          float64
# Count of MORT Measures Better                            float64
# Count of MORT Measures Worse                             float64
# Count of Facility Safety Measures                        float64
# Count of Safety Measures Better                          float64
# Count of Safety Measures Worse                           float64
# Count of Facility READM Measures                         float64
# Count of READM Measures Better                           float64
# Count of READM Measures Worse                            float64
# dtype: object

# %%
# Replace 'Not Avaialble' with NaN in numeric columns
df_hgi_copy.replace('Not Available', np.nan, inplace=True)

# Create df with column means
column_means_2 = df_hgi_copy[columns_to_convert_2].mean().round()

# Fill NaN values in numeric columns with values in column_means_2
df_hgi_copy[columns_to_convert_2] = df_hgi_copy[columns_to_convert_2].fillna(column_means_2)

# %% [markdown]
# > For **imputing values, 'Not Available' is converted to NaN before calculating the mean of each numeric column.** Additionally, we are rounding because all the numbers are counts, and therefore, whole numbers.

# %%
# Check output

df_hgi_copy.eq('Not Available').sum()
# Out:
# Facility Name                                            0
# Address                                                  0
# City/Town                                                0
# State                                                    0
# ZIP Code                                                 0
# County/Parish                                            0
# Telephone Number                                         0
# Hospital Type                                            0
# Hospital Ownership                                       0
# Emergency Services                                       0
# Meets criteria for promoting interoperability of EHRs    0
# Meets criteria for birthing friendly designation         0
# Hospital overall rating                                  0
# Count of Facility MORT Measures                          0
# Count of MORT Measures Better                            0
# Count of MORT Measures Worse                             0
# Count of Facility Safety Measures                        0
# Count of Safety Measures Better                          0
# Count of Safety Measures Worse                           0
# Count of Facility READM Measures                         0
# Count of READM Measures Better                           0
# Count of READM Measures Worse                            0
# dtype: int64

# %%
# Create list identifying columns for imputation with 'N'
columns_to_replace_1 = ['Meets criteria for promoting interoperability of EHRs', 'Meets criteria for birthing friendly designation']

# Impute missing values in these columns with 'N'
df_hgi_copy[columns_to_replace_1] = df_hgi_copy[columns_to_replace_1].fillna('N')

# %% [markdown]
# > **Imputing these values is necessary because the only unique variables present in the column are 'Y' for meeting the criteria and missing values.** Therefore, all blanks will be imputed with 'N' to signify non-compliance with the criteria.

# %%
# Check output

df_hgi_copy[columns_to_replace_1].value_counts()
# Out:
# Meets criteria for promoting interoperability of EHRs  Meets criteria for birthing friendly designation
# Y                                                      Y                                                   1949
#                                                        N                                                    771
# N                                                      N                                                    206
#                                                        Y                                                    116
# Name: count, dtype: int64

# %%
# Check for mixed data types

for col in df_hgi_copy.columns.tolist():
    weird = (df_hgi_copy[[col]].map(type) != df_hgi_copy[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df_hgi_copy[weird]) > 0:
        print (col)

# %% [markdown]
# > Absence of output means there are **no mixed data types present in df_hgi_copy.**

# %%
# Check for null values

df_hgi_copy.isnull().sum()
# Out:
# Facility Name                                            0
# Address                                                  0
# City/Town                                                0
# State                                                    0
# ZIP Code                                                 0
# County/Parish                                            0
# Telephone Number                                         0
# Hospital Type                                            0
# Hospital Ownership                                       0
# Emergency Services                                       0
# Meets criteria for promoting interoperability of EHRs    0
# Meets criteria for birthing friendly designation         0
# Hospital overall rating                                  0
# Count of Facility MORT Measures                          0
# Count of MORT Measures Better                            0
# Count of MORT Measures Worse                             0
# Count of Facility Safety Measures                        0
# Count of Safety Measures Better                          0
# Count of Safety Measures Worse                           0
# Count of Facility READM Measures                         0
# Count of READM Measures Better                           0
# Count of READM Measures Worse                            0
# dtype: int64

# %%
# Rename columns

df_hgi_copy.rename(columns={
    'Meets criteria for promoting interoperability of EHRs': 'Promotes Interoperability of EHRs',
    'Meets criteria for birthing friendly designation': 'Birthing Friendly Facility',
    'Hospital overall rating': 'Hospital Overall Rating',
    'Count of MORT Measures Better': 'MORT Measures Better',
    'Count of MORT Measures Worse': 'MORT Measures Worse',
    'Count of Safety Measures Better': 'Safety Measures Better',
    'Count of Safety Measures Worse': 'Safety Measures Worse',
    'Count of READM Measures Better': 'READM Measures Better',
    'Count of READM Measures Worse': 'READM Measures Worse'
}, inplace=True)

# %%
# Check output

df_hgi_copy.head(1)
# Out:
#                      Facility Name                 Address City/Town State  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE    DOTHAN    AL
#
#    ZIP Code County/Parish Telephone Number         Hospital Type  \
# 0     36301       HOUSTON   (334) 793-8701  Acute Care Hospitals
#
#                             Hospital Ownership Emergency Services  \
# 0  Government - Hospital District or Authority                Yes
#
#   Promotes Interoperability of EHRs Birthing Friendly Facility  \
# 0                                 Y                          Y
#
#   Hospital Overall Rating  Count of Facility MORT Measures  \
# 0                       3                              7.0
#
#    MORT Measures Better  MORT Measures Worse  \
# 0                   1.0                  1.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
#
#    READM Measures Better  READM Measures Worse
# 0                    0.0                   1.0

# %%
# Check shape

df_hgi_copy.shape
# Out:
# (3042, 22)

# %% [markdown]
# # 04. Cleaning and Wrangling HVBP Clinical Outcomes Dataset

# %%
# Check shape

df_hvbp.shape
# Out:
# (2474, 50)

# %%
# Check HVBP Clinical Outcomes dataframe

df_hvbp.head(5)
# Out:
#    Fiscal Year  Facility ID                    Facility Name  \
# 0         2024        10001  SOUTHEAST HEALTH MEDICAL CENTER
# 1         2024        10005         MARSHALL MEDICAL CENTERS
# 2         2024        10006     NORTH ALABAMA MEDICAL CENTER
# 3         2024        10007         MIZELL MEMORIAL HOSPITAL
# 4         2024        10011               ST. VINCENT'S EAST
#
#                       Address   City/Town State  ZIP Code County/Parish  \
# 0      1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301       HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 2         1701 VETERANS DRIVE    FLORENCE    AL     35630    LAUDERDALE
# 3               702 N MAIN ST         OPP    AL     36467     COVINGTON
# 4  50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235     JEFFERSON
#
#    MORT-30-AMI Achievement Threshold  MORT-30-AMI Benchmark  \
# 0                           0.869247               0.887868
# 1                           0.869247               0.887868
# 2                           0.869247               0.887868
# 3                           0.869247               0.887868
# 4                           0.869247               0.887868
#
#   MORT-30-AMI Baseline Rate MORT-30-AMI Performance Rate  \
# 0                  0.856752                     0.880237
# 1                  0.848053                     0.864067
# 2                  0.853581                     0.835481
# 3             Not Available                Not Available
# 4                  0.859425                     0.868485
#
#   MORT-30-AMI Achievement Points MORT-30-AMI Improvement Points  \
# 0                    6 out of 10                     7 out of 9
# 1                    0 out of 10                     4 out of 9
# 2                    0 out of 10                     0 out of 9
# 3                  Not Available                  Not Available
# 4                    0 out of 10                     3 out of 9
#
#   MORT-30-AMI Measure Score  MORT-30-HF Achievement Threshold  \
# 0               7 out of 10                          0.882308
# 1               4 out of 10                          0.882308
# 2               0 out of 10                          0.882308
# 3             Not Available                          0.882308
# 4               3 out of 10                          0.882308
#
#    MORT-30-HF Benchmark MORT-30-HF Baseline Rate MORT-30-HF Performance Rate  \
# 0              0.907733                 0.872117                    0.901917
# 1              0.907733                 0.854099                    0.856339
# 2              0.907733                 0.872053                    0.866923
# 3              0.907733                 0.865767                    0.874346
# 4              0.907733                 0.872458                    0.858843
#
#   MORT-30-HF Achievement Points MORT-30-HF Improvement Points  \
# 0                   7 out of 10                    8 out of 9
# 1                   0 out of 10                    0 out of 9
# 2                   0 out of 10                    0 out of 9
# 3                   0 out of 10                    2 out of 9
# 4                   0 out of 10                    0 out of 9
#
#   MORT-30-HF Measure Score  MORT-30-PN Achievement Threshold  \
# 0              8 out of 10                          0.840281
# 1              0 out of 10                          0.840281
# 2              0 out of 10                          0.840281
# 3              2 out of 10                          0.840281
# 4              0 out of 10                          0.840281
#
#    MORT-30-PN Benchmark MORT-30-PN Baseline Rate MORT-30-PN Performance Rate  \
# 0              0.872976                 0.833710                    0.815392
# 1              0.872976                 0.789256                    0.765414
# 2              0.872976                 0.824859                    0.805453
# 3              0.872976                 0.780354                    0.717560
# 4              0.872976                 0.830560                    0.782196
#
#   MORT-30-PN Achievement Points MORT-30-PN Improvement Points  \
# 0                   0 out of 10                    0 out of 9
# 1                   0 out of 10                    0 out of 9
# 2                   0 out of 10                    0 out of 9
# 3                   0 out of 10                    0 out of 9
# 4                   0 out of 10                    0 out of 9
#
#   MORT-30-PN Measure Score  MORT-30-COPD Achievement Threshold  \
# 0              0 out of 10                            0.916491
# 1              0 out of 10                            0.916491
# 2              0 out of 10                            0.916491
# 3              0 out of 10                            0.916491
# 4              0 out of 10                            0.916491
#
#    MORT-30-COPD Benchmark MORT-30-COPD Baseline Rate  \
# 0                0.934002                   0.905159
# 1                0.934002                   0.892007
# 2                0.934002                   0.908992
# 3                0.934002                   0.917078
# 4                0.934002                   0.905170
#
#   MORT-30-COPD Performance Rate MORT-30-COPD Achievement Points  \
# 0                      0.909860                     0 out of 10
# 1                      0.898823                     0 out of 10
# 2                      0.899168                     0 out of 10
# 3                      0.865260                     0 out of 10
# 4                      0.894272                     0 out of 10
#
#   MORT-30-COPD Improvement Points MORT-30-COPD Measure Score  \
# 0                      1 out of 9                1 out of 10
# 1                      1 out of 9                1 out of 10
# 2                      0 out of 9                0 out of 10
# 3                      0 out of 9                0 out of 10
# 4                      0 out of 9                0 out of 10
#
#    MORT-30-CABG Achievement Threshold  MORT-30-CABG Benchmark  \
# 0                            0.969499                0.980319
# 1                            0.969499                0.980319
# 2                            0.969499                0.980319
# 3                            0.969499                0.980319
# 4                            0.969499                0.980319
#
#   MORT-30-CABG Baseline Rate MORT-30-CABG Performance Rate  \
# 0                   0.954926                      0.958983
# 1              Not Available                 Not Available
# 2                   0.967735                      0.963606
# 3              Not Available                 Not Available
# 4                   0.962992                      0.973731
#
#   MORT-30-CABG Achievement Points MORT-30-CABG Improvement Points  \
# 0                     0 out of 10                      1 out of 9
# 1                   Not Available                   Not Available
# 2                     0 out of 10                      0 out of 9
# 3                   Not Available                   Not Available
# 4                     4 out of 10                      6 out of 9
#
#   MORT-30-CABG Measure Score  COMP-HIP-KNEE Achievement Threshold  \
# 0                1 out of 10                             0.025396
# 1              Not Available                             0.025396
# 2                0 out of 10                             0.025396
# 3              Not Available                             0.025396
# 4                6 out of 10                             0.025396
#
#    COMP-HIP-KNEE Benchmark COMP-HIP-KNEE Baseline Rate  \
# 0                 0.018159                    0.030343
# 1                 0.018159                    0.030034
# 2                 0.018159                    0.035949
# 3                 0.018159                    0.027836
# 4                 0.018159                    0.026092
#
#   COMP-HIP-KNEE Performance Rate COMP-HIP-KNEE Achievement Points  \
# 0                       0.022314                      4 out of 10
# 1                       0.019253                      8 out of 10
# 2                       0.037582                      0 out of 10
# 3                  Not Available                    Not Available
# 4                       0.026132                      0 out of 10
#
#   COMP-HIP-KNEE Improvement Points COMP-HIP-KNEE Measure Score
# 0                       6 out of 9                 6 out of 10
# 1                       9 out of 9                 9 out of 10
# 2                       0 out of 9                 0 out of 10
# 3                    Not Available               Not Available
# 4                       0 out of 9                 0 out of 10

# %% [markdown]
# > **Addressing Duplicates:**
# >
# > During the data profiling phase, **verified the absence of duplicates.**

# %%
# Create copy of Hospital General Information dataframe

df_hvbp_copy = df_hvbp.copy()

# %%
# Check output

df_hvbp_copy.head(5)
# Out:
#    Fiscal Year  Facility ID                    Facility Name  \
# 0         2024        10001  SOUTHEAST HEALTH MEDICAL CENTER
# 1         2024        10005         MARSHALL MEDICAL CENTERS
# 2         2024        10006     NORTH ALABAMA MEDICAL CENTER
# 3         2024        10007         MIZELL MEMORIAL HOSPITAL
# 4         2024        10011               ST. VINCENT'S EAST
#
#                       Address   City/Town State  ZIP Code County/Parish  \
# 0      1108 ROSS CLARK CIRCLE      DOTHAN    AL     36301       HOUSTON
# 1  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957      MARSHALL
# 2         1701 VETERANS DRIVE    FLORENCE    AL     35630    LAUDERDALE
# 3               702 N MAIN ST         OPP    AL     36467     COVINGTON
# 4  50 MEDICAL PARK EAST DRIVE  BIRMINGHAM    AL     35235     JEFFERSON
#
#    MORT-30-AMI Achievement Threshold  MORT-30-AMI Benchmark  \
# 0                           0.869247               0.887868
# 1                           0.869247               0.887868
# 2                           0.869247               0.887868
# 3                           0.869247               0.887868
# 4                           0.869247               0.887868
#
#   MORT-30-AMI Baseline Rate MORT-30-AMI Performance Rate  \
# 0                  0.856752                     0.880237
# 1                  0.848053                     0.864067
# 2                  0.853581                     0.835481
# 3             Not Available                Not Available
# 4                  0.859425                     0.868485
#
#   MORT-30-AMI Achievement Points MORT-30-AMI Improvement Points  \
# 0                    6 out of 10                     7 out of 9
# 1                    0 out of 10                     4 out of 9
# 2                    0 out of 10                     0 out of 9
# 3                  Not Available                  Not Available
# 4                    0 out of 10                     3 out of 9
#
#   MORT-30-AMI Measure Score  MORT-30-HF Achievement Threshold  \
# 0               7 out of 10                          0.882308
# 1               4 out of 10                          0.882308
# 2               0 out of 10                          0.882308
# 3             Not Available                          0.882308
# 4               3 out of 10                          0.882308
#
#    MORT-30-HF Benchmark MORT-30-HF Baseline Rate MORT-30-HF Performance Rate  \
# 0              0.907733                 0.872117                    0.901917
# 1              0.907733                 0.854099                    0.856339
# 2              0.907733                 0.872053                    0.866923
# 3              0.907733                 0.865767                    0.874346
# 4              0.907733                 0.872458                    0.858843
#
#   MORT-30-HF Achievement Points MORT-30-HF Improvement Points  \
# 0                   7 out of 10                    8 out of 9
# 1                   0 out of 10                    0 out of 9
# 2                   0 out of 10                    0 out of 9
# 3                   0 out of 10                    2 out of 9
# 4                   0 out of 10                    0 out of 9
#
#   MORT-30-HF Measure Score  MORT-30-PN Achievement Threshold  \
# 0              8 out of 10                          0.840281
# 1              0 out of 10                          0.840281
# 2              0 out of 10                          0.840281
# 3              2 out of 10                          0.840281
# 4              0 out of 10                          0.840281
#
#    MORT-30-PN Benchmark MORT-30-PN Baseline Rate MORT-30-PN Performance Rate  \
# 0              0.872976                 0.833710                    0.815392
# 1              0.872976                 0.789256                    0.765414
# 2              0.872976                 0.824859                    0.805453
# 3              0.872976                 0.780354                    0.717560
# 4              0.872976                 0.830560                    0.782196
#
#   MORT-30-PN Achievement Points MORT-30-PN Improvement Points  \
# 0                   0 out of 10                    0 out of 9
# 1                   0 out of 10                    0 out of 9
# 2                   0 out of 10                    0 out of 9
# 3                   0 out of 10                    0 out of 9
# 4                   0 out of 10                    0 out of 9
#
#   MORT-30-PN Measure Score  MORT-30-COPD Achievement Threshold  \
# 0              0 out of 10                            0.916491
# 1              0 out of 10                            0.916491
# 2              0 out of 10                            0.916491
# 3              0 out of 10                            0.916491
# 4              0 out of 10                            0.916491
#
#    MORT-30-COPD Benchmark MORT-30-COPD Baseline Rate  \
# 0                0.934002                   0.905159
# 1                0.934002                   0.892007
# 2                0.934002                   0.908992
# 3                0.934002                   0.917078
# 4                0.934002                   0.905170
#
#   MORT-30-COPD Performance Rate MORT-30-COPD Achievement Points  \
# 0                      0.909860                     0 out of 10
# 1                      0.898823                     0 out of 10
# 2                      0.899168                     0 out of 10
# 3                      0.865260                     0 out of 10
# 4                      0.894272                     0 out of 10
#
#   MORT-30-COPD Improvement Points MORT-30-COPD Measure Score  \
# 0                      1 out of 9                1 out of 10
# 1                      1 out of 9                1 out of 10
# 2                      0 out of 9                0 out of 10
# 3                      0 out of 9                0 out of 10
# 4                      0 out of 9                0 out of 10
#
#    MORT-30-CABG Achievement Threshold  MORT-30-CABG Benchmark  \
# 0                            0.969499                0.980319
# 1                            0.969499                0.980319
# 2                            0.969499                0.980319
# 3                            0.969499                0.980319
# 4                            0.969499                0.980319
#
#   MORT-30-CABG Baseline Rate MORT-30-CABG Performance Rate  \
# 0                   0.954926                      0.958983
# 1              Not Available                 Not Available
# 2                   0.967735                      0.963606
# 3              Not Available                 Not Available
# 4                   0.962992                      0.973731
#
#   MORT-30-CABG Achievement Points MORT-30-CABG Improvement Points  \
# 0                     0 out of 10                      1 out of 9
# 1                   Not Available                   Not Available
# 2                     0 out of 10                      0 out of 9
# 3                   Not Available                   Not Available
# 4                     4 out of 10                      6 out of 9
#
#   MORT-30-CABG Measure Score  COMP-HIP-KNEE Achievement Threshold  \
# 0                1 out of 10                             0.025396
# 1              Not Available                             0.025396
# 2                0 out of 10                             0.025396
# 3              Not Available                             0.025396
# 4                6 out of 10                             0.025396
#
#    COMP-HIP-KNEE Benchmark COMP-HIP-KNEE Baseline Rate  \
# 0                 0.018159                    0.030343
# 1                 0.018159                    0.030034
# 2                 0.018159                    0.035949
# 3                 0.018159                    0.027836
# 4                 0.018159                    0.026092
#
#   COMP-HIP-KNEE Performance Rate COMP-HIP-KNEE Achievement Points  \
# 0                       0.022314                      4 out of 10
# 1                       0.019253                      8 out of 10
# 2                       0.037582                      0 out of 10
# 3                  Not Available                    Not Available
# 4                       0.026132                      0 out of 10
#
#   COMP-HIP-KNEE Improvement Points COMP-HIP-KNEE Measure Score
# 0                       6 out of 9                 6 out of 10
# 1                       9 out of 9                 9 out of 10
# 2                       0 out of 9                 0 out of 10
# 3                    Not Available               Not Available
# 4                       0 out of 9                 0 out of 10

# %%
# Create list of columns to keep
columns_to_keep_2 = [
    'Facility ID',
    'Facility Name',
    'Address',
    'City/Town',
    'State',
    'ZIP Code',
    'County/Parish',
    'MORT-30-AMI Benchmark',
    'MORT-30-AMI Performance Rate',
    'MORT-30-HF Benchmark',
    'MORT-30-HF Performance Rate',
    'MORT-30-PN Benchmark',
    'MORT-30-PN Performance Rate',
    'MORT-30-COPD Benchmark',
    'MORT-30-COPD Performance Rate'
]

# Drop all remaining columns
df_hvbp_copy = df_hvbp_copy.drop(columns=df_hvbp_copy.columns.difference(columns_to_keep_2))

# %%
# Check outpput

df_hvbp_copy.head(1)
# Out:
#    Facility ID                    Facility Name                 Address  \
# 0        10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   City/Town State  ZIP Code County/Parish  MORT-30-AMI Benchmark  \
# 0    DOTHAN    AL     36301       HOUSTON               0.887868
#
#   MORT-30-AMI Performance Rate  MORT-30-HF Benchmark  \
# 0                     0.880237              0.907733
#
#   MORT-30-HF Performance Rate  MORT-30-PN Benchmark  \
# 0                    0.901917              0.872976
#
#   MORT-30-PN Performance Rate  MORT-30-COPD Benchmark  \
# 0                    0.815392                0.934002
#
#   MORT-30-COPD Performance Rate
# 0                      0.909860

# %% [markdown]
# > **Addressing Missing Values:**
# >
# > During the data profiling phase, **verified the absence of missing values.**

# %%
# Check for Null values

df_hvbp_copy.eq('Not Available').sum()
# Out:
# Facility ID                        0
# Facility Name                      0
# Address                            0
# City/Town                          0
# State                              0
# ZIP Code                           0
# County/Parish                      0
# MORT-30-AMI Benchmark              0
# MORT-30-AMI Performance Rate     721
# MORT-30-HF Benchmark               0
# MORT-30-HF Performance Rate       80
# MORT-30-PN Benchmark               0
# MORT-30-PN Performance Rate       63
# MORT-30-COPD Benchmark             0
# MORT-30-COPD Performance Rate    362
# dtype: int64

# %%
# Check data types -- To calculate the mean at a later step, quantitative variable columns should be converted to numeric data types

df_hvbp_copy.dtypes
# Out:
# Facility ID                        int64
# Facility Name                     object
# Address                           object
# City/Town                         object
# State                             object
# ZIP Code                           int64
# County/Parish                     object
# MORT-30-AMI Benchmark            float64
# MORT-30-AMI Performance Rate      object
# MORT-30-HF Benchmark             float64
# MORT-30-HF Performance Rate       object
# MORT-30-PN Benchmark             float64
# MORT-30-PN Performance Rate       object
# MORT-30-COPD Benchmark           float64
# MORT-30-COPD Performance Rate     object
# dtype: object

# %%
# Convert 'Not Available' values to NaN -- To calculate the mean of each column
df_hvbp_copy.replace('Not Available', np.nan, inplace=True)

# Create list of columns for which data types we want to convert
columns_to_convert_3 = [
    'MORT-30-AMI Performance Rate',
    'MORT-30-HF Performance Rate',
    'MORT-30-PN Performance Rate',
    'MORT-30-COPD Performance Rate'
]

# Convert columns to numeric
df_hvbp_copy[columns_to_convert_3] = df_hvbp_copy[columns_to_convert_3].apply(pd.to_numeric, errors='ignore', downcast='float').astype('float64')

# %%
# Check datatypes

df_hvbp_copy.dtypes
# Out:
# Facility ID                        int64
# Facility Name                     object
# Address                           object
# City/Town                         object
# State                             object
# ZIP Code                           int64
# County/Parish                     object
# MORT-30-AMI Benchmark            float64
# MORT-30-AMI Performance Rate     float64
# MORT-30-HF Benchmark             float64
# MORT-30-HF Performance Rate      float64
# MORT-30-PN Benchmark             float64
# MORT-30-PN Performance Rate      float64
# MORT-30-COPD Benchmark           float64
# MORT-30-COPD Performance Rate    float64
# dtype: object

# %%
# Create a list of columns for which the mean will be calculated
numeric_columns_w_nans = [
    'MORT-30-AMI Performance Rate',
    'MORT-30-HF Performance Rate',
    'MORT-30-PN Performance Rate',
    'MORT-30-COPD Performance Rate'
]

# Calculate the mean of each column
column_means_3 = df_hvbp_copy[numeric_columns_w_nans].mean()

# Imputate missing values in columns with mean value
df_hvbp_copy.fillna(column_means_3, inplace=True)

# %%
# Check output -- Check for null values

df_hvbp_copy.isnull().sum()
# Out:
# Facility ID                      0
# Facility Name                    0
# Address                          0
# City/Town                        0
# State                            0
# ZIP Code                         0
# County/Parish                    0
# MORT-30-AMI Benchmark            0
# MORT-30-AMI Performance Rate     0
# MORT-30-HF Benchmark             0
# MORT-30-HF Performance Rate      0
# MORT-30-PN Benchmark             0
# MORT-30-PN Performance Rate      0
# MORT-30-COPD Benchmark           0
# MORT-30-COPD Performance Rate    0
# dtype: int64

# %%
# Check for mixed data types

for col in df_hvbp_copy.columns.tolist():
    weird = (df_hvbp_copy[[col]].map(type) != df_hvbp_copy[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df_hvbp_copy[weird]) > 0:
        print (col)

# %% [markdown]
# > Absence of output means there are **no mixed data types present in df_hvbp_copy.**

# %%
# Check shape

df_hvbp_copy.shape
# Out:
# (2474, 15)

# %% [markdown]
# ## 04a. Deriving New Variables - HVBP Clinical Outcomes Dataset

# %%
# Deriving new variables for performance indices

df_hvbp_copy['AMI Normative Performance Index'] = df_hvbp_copy['MORT-30-AMI Performance Rate'] / df_hvbp_copy['MORT-30-AMI Benchmark']
df_hvbp_copy['HF Normative Performance Index'] = df_hvbp_copy['MORT-30-HF Performance Rate'] / df_hvbp_copy['MORT-30-HF Benchmark']
df_hvbp_copy['PN Normative Performance Index'] = df_hvbp_copy['MORT-30-PN Performance Rate'] / df_hvbp_copy['MORT-30-PN Benchmark']
df_hvbp_copy['COPD Normative Performance Index'] = df_hvbp_copy['MORT-30-COPD Performance Rate'] / df_hvbp_copy['MORT-30-COPD Benchmark']

# %% [markdown]
# > **Deriving these new variables quantifies how hospitals compare numerically with their peers.** Values above 1 indicate that a hospital is outperforming its peers.

# %%
#Create threshold
threshold_3 = 1.0

# Derive new variables for comparison flags
df_hvbp_copy['AMI Performance Comparison'] = df_hvbp_copy['AMI Normative Performance Index'].apply(lambda x: 'Outperforms Peers' if x > threshold_3 else 'Meets or Falls Below Peers')
df_hvbp_copy['HF Performance Comparison'] = df_hvbp_copy['HF Normative Performance Index'].apply(lambda x: 'Outperforms Peers' if x > threshold_3 else 'Meets or Falls Below Peers')
df_hvbp_copy['PN Performance Comparison'] = df_hvbp_copy['PN Normative Performance Index'].apply(lambda x: 'Outperforms Peers' if x > threshold_3 else 'Meets or Falls Below Peers')
df_hvbp_copy['COPD Performance Comparison'] = df_hvbp_copy['COPD Normative Performance Index'].apply(lambda x: 'Outperforms Peers' if x > threshold_3 else 'Meets or Falls Below Peers')

# %% [markdown]
# > Creating a **qualitative flag to easily denote whether the hospital outperforms peers, meets peers, or falls below peers.**

# %%
# Check output

df_hvbp_copy.head(1)
# Out:
#    Facility ID                    Facility Name                 Address  \
# 0        10001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   City/Town State  ZIP Code County/Parish  MORT-30-AMI Benchmark  \
# 0    DOTHAN    AL     36301       HOUSTON               0.887868
#
#    MORT-30-AMI Performance Rate  MORT-30-HF Benchmark  \
# 0                      0.880237              0.907733
#
#    MORT-30-HF Performance Rate  MORT-30-PN Benchmark  \
# 0                     0.901917              0.872976
#
#    MORT-30-PN Performance Rate  MORT-30-COPD Benchmark  \
# 0                     0.815392                0.934002
#
#    MORT-30-COPD Performance Rate  AMI Normative Performance Index  \
# 0                        0.90986                         0.991405
#
#    HF Normative Performance Index  PN Normative Performance Index  \
# 0                        0.993593                        0.934037
#
#    COPD Normative Performance Index  AMI Performance Comparison  \
# 0                          0.974152  Meets or Falls Below Peers
#
#     HF Performance Comparison   PN Performance Comparison  \
# 0  Meets or Falls Below Peers  Meets or Falls Below Peers
#
#   COPD Performance Comparison
# 0  Meets or Falls Below Peers

# %%
# Check shape

df_hvbp_copy.shape
# Out:
# (2474, 23)

# %% [markdown]
# # 05. Data Merging

# %%
# Create list of key columns to merge df_hgi_copy and df_hvbp_copy
merge_columns_2_3 = ['Facility Name', 'Address', 'City/Town', 'State', 'ZIP Code', 'County/Parish']

# Merge df_hgi_copy and df_hvbp
df_hgi_hvbp_merged = df_hgi_copy.merge(df_hvbp_copy, on=merge_columns_2_3, indicator=True)

# %%
# Check output

df_hgi_hvbp_merged.head(1)
# Out:
#                      Facility Name                 Address City/Town State  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE    DOTHAN    AL
#
#    ZIP Code County/Parish Telephone Number         Hospital Type  \
# 0     36301       HOUSTON   (334) 793-8701  Acute Care Hospitals
#
#                             Hospital Ownership Emergency Services  \
# 0  Government - Hospital District or Authority                Yes
#
#   Promotes Interoperability of EHRs Birthing Friendly Facility  \
# 0                                 Y                          Y
#
#   Hospital Overall Rating  Count of Facility MORT Measures  \
# 0                       3                              7.0
#
#    MORT Measures Better  MORT Measures Worse  \
# 0                   1.0                  1.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
#
#    READM Measures Better  READM Measures Worse  Facility ID  \
# 0                    0.0                   1.0        10001
#
#    MORT-30-AMI Benchmark  MORT-30-AMI Performance Rate  MORT-30-HF Benchmark  \
# 0               0.887868                      0.880237              0.907733
#
#    MORT-30-HF Performance Rate  MORT-30-PN Benchmark  \
# 0                     0.901917              0.872976
#
#    MORT-30-PN Performance Rate  MORT-30-COPD Benchmark  \
# 0                     0.815392                0.934002
#
#    MORT-30-COPD Performance Rate  AMI Normative Performance Index  \
# 0                        0.90986                         0.991405
#
#    HF Normative Performance Index  PN Normative Performance Index  \
# 0                        0.993593                        0.934037
#
#    COPD Normative Performance Index  AMI Performance Comparison  \
# 0                          0.974152  Meets or Falls Below Peers
#
#     HF Performance Comparison   PN Performance Comparison  \
# 0  Meets or Falls Below Peers  Meets or Falls Below Peers
#
#   COPD Performance Comparison _merge
# 0  Meets or Falls Below Peers   both

# %%
# Check _merge flag

df_hgi_hvbp_merged['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both          2301
# left_only        0
# right_only       0
# Name: count, dtype: int64

# %%
# Remove _merge flag

df_hgi_hvbp_merged_copy = df_hgi_hvbp_merged.drop(columns='_merge')

# %%
# Check output

df_hgi_hvbp_merged_copy.head(1)
# Out:
#                      Facility Name                 Address City/Town State  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE    DOTHAN    AL
#
#    ZIP Code County/Parish Telephone Number         Hospital Type  \
# 0     36301       HOUSTON   (334) 793-8701  Acute Care Hospitals
#
#                             Hospital Ownership Emergency Services  \
# 0  Government - Hospital District or Authority                Yes
#
#   Promotes Interoperability of EHRs Birthing Friendly Facility  \
# 0                                 Y                          Y
#
#   Hospital Overall Rating  Count of Facility MORT Measures  \
# 0                       3                              7.0
#
#    MORT Measures Better  MORT Measures Worse  \
# 0                   1.0                  1.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
#
#    READM Measures Better  READM Measures Worse  Facility ID  \
# 0                    0.0                   1.0        10001
#
#    MORT-30-AMI Benchmark  MORT-30-AMI Performance Rate  MORT-30-HF Benchmark  \
# 0               0.887868                      0.880237              0.907733
#
#    MORT-30-HF Performance Rate  MORT-30-PN Benchmark  \
# 0                     0.901917              0.872976
#
#    MORT-30-PN Performance Rate  MORT-30-COPD Benchmark  \
# 0                     0.815392                0.934002
#
#    MORT-30-COPD Performance Rate  AMI Normative Performance Index  \
# 0                        0.90986                         0.991405
#
#    HF Normative Performance Index  PN Normative Performance Index  \
# 0                        0.993593                        0.934037
#
#    COPD Normative Performance Index  AMI Performance Comparison  \
# 0                          0.974152  Meets or Falls Below Peers
#
#     HF Performance Comparison   PN Performance Comparison  \
# 0  Meets or Falls Below Peers  Meets or Falls Below Peers
#
#   COPD Performance Comparison
# 0  Meets or Falls Below Peers

# %%
# Check shape

df_hgi_hvbp_merged_copy.shape
# Out:
# (2301, 39)

# %%
# Create list of key columns to merge df_hgi_hvbp_merged_copy and df_hrrp_copy
merge_columns_1_2_3 = ['Facility Name', 'Facility ID', 'State']

# Merge df_hgi_hvbp_merged_copy and df_hrrp
df_hrrp_hgi_hvbp_merged = df_hrrp_copy.merge(df_hgi_hvbp_merged_copy, on=merge_columns_1_2_3, indicator=True)

# %%
# Check output

df_hrrp_hgi_hvbp_merged.head(1)
# Out:
#                      Facility Name  Facility ID State            Measure Name  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL  READM-30-HIP-KNEE-HRRP
#
#    Excess Readmission Ratio  Observed Readmission Rate  \
# 0                    0.8916                     3.5325
#
#    Expected Readmission Rate Excess Readmissions Threshold  \
# 0                     3.9618               Below Threshold
#
#                   Address City/Town  ZIP Code County/Parish Telephone Number  \
# 0  1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON   (334) 793-8701
#
#           Hospital Type                           Hospital Ownership  \
# 0  Acute Care Hospitals  Government - Hospital District or Authority
#
#   Emergency Services Promotes Interoperability of EHRs  \
# 0                Yes                                 Y
#
#   Birthing Friendly Facility Hospital Overall Rating  \
# 0                          Y                       3
#
#    Count of Facility MORT Measures  MORT Measures Better  MORT Measures Worse  \
# 0                              7.0                   1.0                  1.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
#
#    READM Measures Better  READM Measures Worse  MORT-30-AMI Benchmark  \
# 0                    0.0                   1.0               0.887868
#
#    MORT-30-AMI Performance Rate  MORT-30-HF Benchmark  \
# 0                      0.880237              0.907733
#
#    MORT-30-HF Performance Rate  MORT-30-PN Benchmark  \
# 0                     0.901917              0.872976
#
#    MORT-30-PN Performance Rate  MORT-30-COPD Benchmark  \
# 0                     0.815392                0.934002
#
#    MORT-30-COPD Performance Rate  AMI Normative Performance Index  \
# 0                        0.90986                         0.991405
#
#    HF Normative Performance Index  PN Normative Performance Index  \
# 0                        0.993593                        0.934037
#
#    COPD Normative Performance Index  AMI Performance Comparison  \
# 0                          0.974152  Meets or Falls Below Peers
#
#     HF Performance Comparison   PN Performance Comparison  \
# 0  Meets or Falls Below Peers  Meets or Falls Below Peers
#
#   COPD Performance Comparison _merge
# 0  Meets or Falls Below Peers   both

# %%
# Check _merge flag

df_hrrp_hgi_hvbp_merged['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both          10344
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
# Remove _merge flag

df_hrrp_hgi_hvbp_merged_copy = df_hrrp_hgi_hvbp_merged.drop(columns='_merge')

# %%
# Check output

df_hrrp_hgi_hvbp_merged_copy.head(1)
# Out:
#                      Facility Name  Facility ID State            Measure Name  \
# 0  SOUTHEAST HEALTH MEDICAL CENTER        10001    AL  READM-30-HIP-KNEE-HRRP
#
#    Excess Readmission Ratio  Observed Readmission Rate  \
# 0                    0.8916                     3.5325
#
#    Expected Readmission Rate Excess Readmissions Threshold  \
# 0                     3.9618               Below Threshold
#
#                   Address City/Town  ZIP Code County/Parish Telephone Number  \
# 0  1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON   (334) 793-8701
#
#           Hospital Type                           Hospital Ownership  \
# 0  Acute Care Hospitals  Government - Hospital District or Authority
#
#   Emergency Services Promotes Interoperability of EHRs  \
# 0                Yes                                 Y
#
#   Birthing Friendly Facility Hospital Overall Rating  \
# 0                          Y                       3
#
#    Count of Facility MORT Measures  MORT Measures Better  MORT Measures Worse  \
# 0                              7.0                   1.0                  1.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
#
#    READM Measures Better  READM Measures Worse  MORT-30-AMI Benchmark  \
# 0                    0.0                   1.0               0.887868
#
#    MORT-30-AMI Performance Rate  MORT-30-HF Benchmark  \
# 0                      0.880237              0.907733
#
#    MORT-30-HF Performance Rate  MORT-30-PN Benchmark  \
# 0                     0.901917              0.872976
#
#    MORT-30-PN Performance Rate  MORT-30-COPD Benchmark  \
# 0                     0.815392                0.934002
#
#    MORT-30-COPD Performance Rate  AMI Normative Performance Index  \
# 0                        0.90986                         0.991405
#
#    HF Normative Performance Index  PN Normative Performance Index  \
# 0                        0.993593                        0.934037
#
#    COPD Normative Performance Index  AMI Performance Comparison  \
# 0                          0.974152  Meets or Falls Below Peers
#
#     HF Performance Comparison   PN Performance Comparison  \
# 0  Meets or Falls Below Peers  Meets or Falls Below Peers
#
#   COPD Performance Comparison
# 0  Meets or Falls Below Peers

# %%
# Check Shape

df_hrrp_hgi_hvbp_merged_copy.shape
# Out:
# (10344, 44)

# %% [markdown]
# # 06. Consistency Checks on Integreated Dataset

# %%
# Create list for reordering column names
column_name_order = [
    'Facility ID',
    'Facility Name',
    'State',
    'Address',
    'City/Town',
    'ZIP Code',
    'County/Parish',
    'Telephone Number',
    'Hospital Type',
    'Hospital Ownership',
    'Emergency Services',
    'Promotes Interoperability of EHRs',
    'Birthing Friendly Facility',
    'Hospital Overall Rating',
    'Measure Name',	
    'Excess Readmission Ratio', 	
    'Observed Readmission Rate', 	
    'Expected Readmission Rate', 	
    'Excess Readmissions Threshold',
    'Count of Facility MORT Measures',
    'MORT Measures Better',
    'MORT Measures Worse',
    'Count of Facility Safety Measures', 	
    'Safety Measures Better', 	
    'Safety Measures Worse', 	
    'Count of Facility READM Measures', 	
    'READM Measures Better', 	
    'READM Measures Worse',
    'MORT-30-AMI Benchmark', 	
    'MORT-30-AMI Performance Rate', 
    'AMI Normative Performance Index', 
    'AMI Performance Comparison',
    'MORT-30-HF Benchmark', 	
    'MORT-30-HF Performance Rate', 
    'HF Normative Performance Index', 
    'HF Performance Comparison',
    'MORT-30-PN Benchmark', 	
    'MORT-30-PN Performance Rate', 
    'PN Normative Performance Index', 
    'PN Performance Comparison',
    'MORT-30-COPD Benchmark', 	
    'MORT-30-COPD Performance Rate', 
    'COPD Normative Performance Index', 
    'COPD Performance Comparison'
]

# %%
# Rearrange column names

df_hrrp_hgi_hvbp_merged_copy = df_hrrp_hgi_hvbp_merged_copy[column_name_order]

# %%
# Check output

df_hrrp_hgi_hvbp_merged_copy.head(1)
# Out:
#    Facility ID                    Facility Name State                 Address  \
# 0        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL  1108 ROSS CLARK CIRCLE
#
#   City/Town  ZIP Code County/Parish Telephone Number         Hospital Type  \
# 0    DOTHAN     36301       HOUSTON   (334) 793-8701  Acute Care Hospitals
#
#                             Hospital Ownership Emergency Services  \
# 0  Government - Hospital District or Authority                Yes
#
#   Promotes Interoperability of EHRs Birthing Friendly Facility  \
# 0                                 Y                          Y
#
#   Hospital Overall Rating            Measure Name  Excess Readmission Ratio  \
# 0                       3  READM-30-HIP-KNEE-HRRP                    0.8916
#
#    Observed Readmission Rate  Expected Readmission Rate  \
# 0                     3.5325                     3.9618
#
#   Excess Readmissions Threshold  Count of Facility MORT Measures  \
# 0               Below Threshold                              7.0
#
#    MORT Measures Better  MORT Measures Worse  \
# 0                   1.0                  1.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
#
#    READM Measures Better  READM Measures Worse  MORT-30-AMI Benchmark  \
# 0                    0.0                   1.0               0.887868
#
#    MORT-30-AMI Performance Rate  AMI Normative Performance Index  \
# 0                      0.880237                         0.991405
#
#    AMI Performance Comparison  MORT-30-HF Benchmark  \
# 0  Meets or Falls Below Peers              0.907733
#
#    MORT-30-HF Performance Rate  HF Normative Performance Index  \
# 0                     0.901917                        0.993593
#
#     HF Performance Comparison  MORT-30-PN Benchmark  \
# 0  Meets or Falls Below Peers              0.872976
#
#    MORT-30-PN Performance Rate  PN Normative Performance Index  \
# 0                     0.815392                        0.934037
#
#     PN Performance Comparison  MORT-30-COPD Benchmark  \
# 0  Meets or Falls Below Peers                0.934002
#
#    MORT-30-COPD Performance Rate  COPD Normative Performance Index  \
# 0                        0.90986                          0.974152
#
#   COPD Performance Comparison
# 0  Meets or Falls Below Peers

# %%
# Check shape -- To ensure all colmuns are included

df_hrrp_hgi_hvbp_merged_copy.shape
# Out:
# (10344, 44)

# %%
# Check for null values

df_hrrp_hgi_hvbp_merged_copy.isnull().sum()
# Out:
# Facility ID                          0
# Facility Name                        0
# State                                0
# Address                              0
# City/Town                            0
# ZIP Code                             0
# County/Parish                        0
# Telephone Number                     0
# Hospital Type                        0
# Hospital Ownership                   0
# Emergency Services                   0
# Promotes Interoperability of EHRs    0
# Birthing Friendly Facility           0
# Hospital Overall Rating              0
# Measure Name                         0
# Excess Readmission Ratio             0
# Observed Readmission Rate            0
# Expected Readmission Rate            0
# Excess Readmissions Threshold        0
# Count of Facility MORT Measures      0
# MORT Measures Better                 0
# MORT Measures Worse                  0
# Count of Facility Safety Measures    0
# Safety Measures Better               0
# Safety Measures Worse                0
# Count of Facility READM Measures     0
# READM Measures Better                0
# READM Measures Worse                 0
# MORT-30-AMI Benchmark                0
# MORT-30-AMI Performance Rate         0
# AMI Normative Performance Index      0
# AMI Performance Comparison           0
# MORT-30-HF Benchmark                 0
# MORT-30-HF Performance Rate          0
# HF Normative Performance Index       0
# HF Performance Comparison            0
# MORT-30-PN Benchmark                 0
# MORT-30-PN Performance Rate          0
# PN Normative Performance Index       0
# PN Performance Comparison            0
# MORT-30-COPD Benchmark               0
# MORT-30-COPD Performance Rate        0
# COPD Normative Performance Index     0
# COPD Performance Comparison          0
# dtype: int64

# %%
# Check for mixed data types

for col in df_hrrp_hgi_hvbp_merged_copy.columns.tolist():
    weird = (df_hrrp_hgi_hvbp_merged[[col]].map(type) != df_hrrp_hgi_hvbp_merged[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df_hrrp_hgi_hvbp_merged[weird]) > 0:
        print (col)

# %% [markdown]
# > **Absence of mixed data types in df_hrrp_hgi_hvbp_merged_copy** results in no output.

# %%
# Check for duplicates

df_dups = df_hrrp_hgi_hvbp_merged_copy[df_hrrp_hgi_hvbp_merged_copy.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Facility ID, Facility Name, State, Address, City/Town, ZIP Code, County/Parish, Telephone Number, Hospital Type, Hospital Ownership, Emergency Services, Promotes Interoperability of EHRs, Birthing Friendly Facility, Hospital Overall Rating, Measure Name, Excess Readmission Ratio, Observed Readmission Rate, Expected Readmission Rate, Excess Readmissions Threshold, Count of Facility MORT Measures, MORT Measures Better, MORT Measures Worse, Count of Facility Safety Measures, Safety Measures Better, Safety Measures Worse, Count of Facility READM Measures, READM Measures Better, READM Measures Worse, MORT-30-AMI Benchmark, MORT-30-AMI Performance Rate, AMI Normative Performance Index, AMI Performance Comparison, MORT-30-HF Benchmark, MORT-30-HF Performance Rate, HF Normative Performance Index, HF Performance Comparison, MORT-30-PN Benchmark, MORT-30-PN Performance Rate, PN Normative Performance Index, PN Performance Comparison, MORT-30-COPD Benchmark, MORT-30-COPD Performance Rate, COPD Normative Performance Index, COPD Performance Comparison]
# Index: []

# %% [markdown]
# > Absence of row contents means **there are no rows of duplicated data**.

# %%
# Check integrated dataframe

df_hrrp_hgi_hvbp_merged_copy.head(10)
# Out:
#    Facility ID                    Facility Name State  \
# 0        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL
# 1        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL
# 2        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL
# 3        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL
# 4        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL
# 5        10001  SOUTHEAST HEALTH MEDICAL CENTER    AL
# 6        10005         MARSHALL MEDICAL CENTERS    AL
# 7        10005         MARSHALL MEDICAL CENTERS    AL
# 8        10005         MARSHALL MEDICAL CENTERS    AL
# 9        10005         MARSHALL MEDICAL CENTERS    AL
#
#                       Address City/Town  ZIP Code County/Parish  \
# 0      1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON
# 1      1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON
# 2      1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON
# 3      1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON
# 4      1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON
# 5      1108 ROSS CLARK CIRCLE    DOTHAN     36301       HOUSTON
# 6  2505 U S HIGHWAY 431 NORTH      BOAZ     35957      MARSHALL
# 7  2505 U S HIGHWAY 431 NORTH      BOAZ     35957      MARSHALL
# 8  2505 U S HIGHWAY 431 NORTH      BOAZ     35957      MARSHALL
# 9  2505 U S HIGHWAY 431 NORTH      BOAZ     35957      MARSHALL
#
#   Telephone Number         Hospital Type  \
# 0   (334) 793-8701  Acute Care Hospitals
# 1   (334) 793-8701  Acute Care Hospitals
# 2   (334) 793-8701  Acute Care Hospitals
# 3   (334) 793-8701  Acute Care Hospitals
# 4   (334) 793-8701  Acute Care Hospitals
# 5   (334) 793-8701  Acute Care Hospitals
# 6   (256) 593-8310  Acute Care Hospitals
# 7   (256) 593-8310  Acute Care Hospitals
# 8   (256) 593-8310  Acute Care Hospitals
# 9   (256) 593-8310  Acute Care Hospitals
#
#                             Hospital Ownership Emergency Services  \
# 0  Government - Hospital District or Authority                Yes
# 1  Government - Hospital District or Authority                Yes
# 2  Government - Hospital District or Authority                Yes
# 3  Government - Hospital District or Authority                Yes
# 4  Government - Hospital District or Authority                Yes
# 5  Government - Hospital District or Authority                Yes
# 6  Government - Hospital District or Authority                Yes
# 7  Government - Hospital District or Authority                Yes
# 8  Government - Hospital District or Authority                Yes
# 9  Government - Hospital District or Authority                Yes
#
#   Promotes Interoperability of EHRs Birthing Friendly Facility  \
# 0                                 Y                          Y
# 1                                 Y                          Y
# 2                                 Y                          Y
# 3                                 Y                          Y
# 4                                 Y                          Y
# 5                                 Y                          Y
# 6                                 Y                          N
# 7                                 Y                          N
# 8                                 Y                          N
# 9                                 Y                          N
#
#   Hospital Overall Rating            Measure Name  Excess Readmission Ratio  \
# 0                       3  READM-30-HIP-KNEE-HRRP                    0.8916
# 1                       3        READM-30-HF-HRRP                    1.1003
# 2                       3       READM-30-AMI-HRRP                    0.9332
# 3                       3        READM-30-PN-HRRP                    0.9871
# 4                       3      READM-30-CABG-HRRP                    0.9517
# 5                       3      READM-30-COPD-HRRP                    0.9803
# 6                       2      READM-30-COPD-HRRP                    0.8784
# 7                       2        READM-30-PN-HRRP                    0.9497
# 8                       2        READM-30-HF-HRRP                    0.9885
# 9                       2  READM-30-HIP-KNEE-HRRP                    0.7977
#
#    Observed Readmission Rate  Expected Readmission Rate  \
# 0                     3.5325                     3.9618
# 1                    23.1263                    21.0184
# 2                    12.9044                    13.8283
# 3                    17.0529                    17.2762
# 4                     9.8131                    10.3112
# 5                    18.1837                    18.5483
# 6                    16.2476                    18.4967
# 7                    15.2494                    16.0567
# 8                    19.1975                    19.4209
# 9                     3.7634                     4.7181
#
#   Excess Readmissions Threshold  Count of Facility MORT Measures  \
# 0               Below Threshold                              7.0
# 1               Above Threshold                              7.0
# 2               Below Threshold                              7.0
# 3               Below Threshold                              7.0
# 4               Below Threshold                              7.0
# 5               Below Threshold                              7.0
# 6               Below Threshold                              6.0
# 7               Below Threshold                              6.0
# 8               Below Threshold                              6.0
# 9               Below Threshold                              6.0
#
#    MORT Measures Better  MORT Measures Worse  \
# 0                   1.0                  1.0
# 1                   1.0                  1.0
# 2                   1.0                  1.0
# 3                   1.0                  1.0
# 4                   1.0                  1.0
# 5                   1.0                  1.0
# 6                   0.0                  2.0
# 7                   0.0                  2.0
# 8                   0.0                  2.0
# 9                   0.0                  2.0
#
#    Count of Facility Safety Measures  Safety Measures Better  \
# 0                                8.0                     2.0
# 1                                8.0                     2.0
# 2                                8.0                     2.0
# 3                                8.0                     2.0
# 4                                8.0                     2.0
# 5                                8.0                     2.0
# 6                                7.0                     0.0
# 7                                7.0                     0.0
# 8                                7.0                     0.0
# 9                                7.0                     0.0
#
#    Safety Measures Worse  Count of Facility READM Measures  \
# 0                    0.0                              11.0
# 1                    0.0                              11.0
# 2                    0.0                              11.0
# 3                    0.0                              11.0
# 4                    0.0                              11.0
# 5                    0.0                              11.0
# 6                    1.0                              10.0
# 7                    1.0                              10.0
# 8                    1.0                              10.0
# 9                    1.0                              10.0
#
#    READM Measures Better  READM Measures Worse  MORT-30-AMI Benchmark  \
# 0                    0.0                   1.0               0.887868
# 1                    0.0                   1.0               0.887868
# 2                    0.0                   1.0               0.887868
# 3                    0.0                   1.0               0.887868
# 4                    0.0                   1.0               0.887868
# 5                    0.0                   1.0               0.887868
# 6                    0.0                   0.0               0.887868
# 7                    0.0                   0.0               0.887868
# 8                    0.0                   0.0               0.887868
# 9                    0.0                   0.0               0.887868
#
#    MORT-30-AMI Performance Rate  AMI Normative Performance Index  \
# 0                      0.880237                         0.991405
# 1                      0.880237                         0.991405
# 2                      0.880237                         0.991405
# 3                      0.880237                         0.991405
# 4                      0.880237                         0.991405
# 5                      0.880237                         0.991405
# 6                      0.864067                         0.973193
# 7                      0.864067                         0.973193
# 8                      0.864067                         0.973193
# 9                      0.864067                         0.973193
#
#    AMI Performance Comparison  MORT-30-HF Benchmark  \
# 0  Meets or Falls Below Peers              0.907733
# 1  Meets or Falls Below Peers              0.907733
# 2  Meets or Falls Below Peers              0.907733
# 3  Meets or Falls Below Peers              0.907733
# 4  Meets or Falls Below Peers              0.907733
# 5  Meets or Falls Below Peers              0.907733
# 6  Meets or Falls Below Peers              0.907733
# 7  Meets or Falls Below Peers              0.907733
# 8  Meets or Falls Below Peers              0.907733
# 9  Meets or Falls Below Peers              0.907733
#
#    MORT-30-HF Performance Rate  HF Normative Performance Index  \
# 0                     0.901917                        0.993593
# 1                     0.901917                        0.993593
# 2                     0.901917                        0.993593
# 3                     0.901917                        0.993593
# 4                     0.901917                        0.993593
# 5                     0.901917                        0.993593
# 6                     0.856339                        0.943382
# 7                     0.856339                        0.943382
# 8                     0.856339                        0.943382
# 9                     0.856339                        0.943382
#
#     HF Performance Comparison  MORT-30-PN Benchmark  \
# 0  Meets or Falls Below Peers              0.872976
# 1  Meets or Falls Below Peers              0.872976
# 2  Meets or Falls Below Peers              0.872976
# 3  Meets or Falls Below Peers              0.872976
# 4  Meets or Falls Below Peers              0.872976
# 5  Meets or Falls Below Peers              0.872976
# 6  Meets or Falls Below Peers              0.872976
# 7  Meets or Falls Below Peers              0.872976
# 8  Meets or Falls Below Peers              0.872976
# 9  Meets or Falls Below Peers              0.872976
#
#    MORT-30-PN Performance Rate  PN Normative Performance Index  \
# 0                     0.815392                        0.934037
# 1                     0.815392                        0.934037
# 2                     0.815392                        0.934037
# 3                     0.815392                        0.934037
# 4                     0.815392                        0.934037
# 5                     0.815392                        0.934037
# 6                     0.765414                        0.876787
# 7                     0.765414                        0.876787
# 8                     0.765414                        0.876787
# 9                     0.765414                        0.876787
#
#     PN Performance Comparison  MORT-30-COPD Benchmark  \
# 0  Meets or Falls Below Peers                0.934002
# 1  Meets or Falls Below Peers                0.934002
# 2  Meets or Falls Below Peers                0.934002
# 3  Meets or Falls Below Peers                0.934002
# 4  Meets or Falls Below Peers                0.934002
# 5  Meets or Falls Below Peers                0.934002
# 6  Meets or Falls Below Peers                0.934002
# 7  Meets or Falls Below Peers                0.934002
# 8  Meets or Falls Below Peers                0.934002
# 9  Meets or Falls Below Peers                0.934002
#
#    MORT-30-COPD Performance Rate  COPD Normative Performance Index  \
# 0                       0.909860                          0.974152
# 1                       0.909860                          0.974152
# 2                       0.909860                          0.974152
# 3                       0.909860                          0.974152
# 4                       0.909860                          0.974152
# 5                       0.909860                          0.974152
# 6                       0.898823                          0.962335
# 7                       0.898823                          0.962335
# 8                       0.898823                          0.962335
# 9                       0.898823                          0.962335
#
#   COPD Performance Comparison
# 0  Meets or Falls Below Peers
# 1  Meets or Falls Below Peers
# 2  Meets or Falls Below Peers
# 3  Meets or Falls Below Peers
# 4  Meets or Falls Below Peers
# 5  Meets or Falls Below Peers
# 6  Meets or Falls Below Peers
# 7  Meets or Falls Below Peers
# 8  Meets or Falls Below Peers
# 9  Meets or Falls Below Peers

# %%
# Find summary statitics of merged datset

df_hrrp_hgi_hvbp_merged_copy.describe(include='all')
# Out:
#           Facility ID         Facility Name  State                 Address  \
# count    10344.000000                 10344  10344                   10344
# unique            NaN                  2221     49                    2259
# top               NaN  MERCY MEDICAL CENTER     CA  1 MEDICAL CENTER DRIVE
# freq              NaN                    21    942                      17
# mean    255746.089907                   NaN    NaN                     NaN
# std     157604.085506                   NaN    NaN                     NaN
# min      10001.000000                   NaN    NaN                     NaN
# 25%     110002.750000                   NaN    NaN                     NaN
# 50%     250040.000000                   NaN    NaN                     NaN
# 75%     390009.750000                   NaN    NaN                     NaN
# max     670122.000000                   NaN    NaN                     NaN
#
#        City/Town      ZIP Code County/Parish Telephone Number  \
# count      10344  10344.000000         10344            10344
# unique      1471           NaN           817             2259
# top      CHICAGO           NaN   LOS ANGELES   (952) 892-2101
# freq          72           NaN           239               23
# mean         NaN  51012.222061           NaN              NaN
# std          NaN  28088.904883           NaN              NaN
# min          NaN   1040.000000           NaN              NaN
# 25%          NaN  30077.500000           NaN              NaN
# 50%          NaN  48060.000000           NaN              NaN
# 75%          NaN  76015.000000           NaN              NaN
# max          NaN  99801.000000           NaN              NaN
#
#                Hospital Type              Hospital Ownership  \
# count                  10344                           10344
# unique                     1                              10
# top     Acute Care Hospitals  Voluntary non-profit - Private
# freq                   10344                            5360
# mean                     NaN                             NaN
# std                      NaN                             NaN
# min                      NaN                             NaN
# 25%                      NaN                             NaN
# 50%                      NaN                             NaN
# 75%                      NaN                             NaN
# max                      NaN                             NaN
#
#        Emergency Services Promotes Interoperability of EHRs  \
# count               10344                             10344
# unique                  2                                 2
# top                   Yes                                 Y
# freq                 9986                              9841
# mean                  NaN                               NaN
# std                   NaN                               NaN
# min                   NaN                               NaN
# 25%                   NaN                               NaN
# 50%                   NaN                               NaN
# 75%                   NaN                               NaN
# max                   NaN                               NaN
#
#        Birthing Friendly Facility Hospital Overall Rating      Measure Name  \
# count                       10344                   10344             10344
# unique                          2                       5                 6
# top                             Y                       3  READM-30-PN-HRRP
# freq                         8207                    2925              2241
# mean                          NaN                     NaN               NaN
# std                           NaN                     NaN               NaN
# min                           NaN                     NaN               NaN
# 25%                           NaN                     NaN               NaN
# 50%                           NaN                     NaN               NaN
# 75%                           NaN                     NaN               NaN
# max                           NaN                     NaN               NaN
#
#         Excess Readmission Ratio  Observed Readmission Rate  \
# count               10344.000000               10344.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                    1.002792                  15.164002
# std                     0.076837                   5.434114
# min                     0.615900                   2.611200
# 25%                     0.957900                  12.457175
# 50%                     0.998400                  16.535250
# 75%                     1.043325                  19.094100
# max                     1.507600                  28.147200
#
#         Expected Readmission Rate Excess Readmissions Threshold  \
# count                10344.000000                         10344
# unique                        NaN                             2
# top                           NaN               Below Threshold
# freq                          NaN                          5284
# mean                    15.124622                           NaN
# std                      5.308432                           NaN
# min                      2.830700                           NaN
# 25%                     12.501775                           NaN
# 50%                     16.627400                           NaN
# 75%                     19.170575                           NaN
# max                     25.992900                           NaN
#
#         Count of Facility MORT Measures  MORT Measures Better  \
# count                      10344.000000          10344.000000
# unique                              NaN                   NaN
# top                                 NaN                   NaN
# freq                                NaN                   NaN
# mean                           5.775329              0.236659
# std                            1.378481              0.628581
# min                            1.000000              0.000000
# 25%                            5.000000              0.000000
# 50%                            6.000000              0.000000
# 75%                            7.000000              0.000000
# max                            7.000000              4.000000
#
#         MORT Measures Worse  Count of Facility Safety Measures  \
# count          10344.000000                       10344.000000
# unique                  NaN                                NaN
# top                     NaN                                NaN
# freq                    NaN                                NaN
# mean               0.174207                           6.429911
# std                0.490663                           1.651007
# min                0.000000                           1.000000
# 25%                0.000000                           6.000000
# 50%                0.000000                           7.000000
# 75%                0.000000                           8.000000
# max                4.000000                           8.000000
#
#         Safety Measures Better  Safety Measures Worse  \
# count             10344.000000           10344.000000
# unique                     NaN                    NaN
# top                        NaN                    NaN
# freq                       NaN                    NaN
# mean                  1.111176               0.343194
# std                   1.007856               0.615917
# min                   0.000000               0.000000
# 25%                   0.000000               0.000000
# 50%                   1.000000               0.000000
# 75%                   2.000000               1.000000
# max                   6.000000               4.000000
#
#         Count of Facility READM Measures  READM Measures Better  \
# count                       10344.000000           10344.000000
# unique                               NaN                    NaN
# top                                  NaN                    NaN
# freq                                 NaN                    NaN
# mean                            9.142885               0.417923
# std                             1.754948               0.718959
# min                             1.000000               0.000000
# 25%                             8.000000               0.000000
# 50%                             9.000000               0.000000
# 75%                            11.000000               1.000000
# max                            11.000000               5.000000
#
#         READM Measures Worse  MORT-30-AMI Benchmark  \
# count           10344.000000           1.034400e+04
# unique                   NaN                    NaN
# top                      NaN                    NaN
# freq                     NaN                    NaN
# mean                0.915507           8.878680e-01
# std                 1.130392           1.515528e-13
# min                 0.000000           8.878680e-01
# 25%                 0.000000           8.878680e-01
# 50%                 1.000000           8.878680e-01
# 75%                 2.000000           8.878680e-01
# max                 7.000000           8.878680e-01
#
#         MORT-30-AMI Performance Rate  AMI Normative Performance Index  \
# count                   10344.000000                     10344.000000
# unique                           NaN                              NaN
# top                              NaN                              NaN
# freq                             NaN                              NaN
# mean                        0.874252                         0.984665
# std                         0.010203                         0.011492
# min                         0.830732                         0.935648
# 25%                         0.869248                         0.979029
# 50%                         0.874233                         0.984643
# 75%                         0.879887                         0.991011
# max                         0.909650                         1.024533
#
#         AMI Performance Comparison  MORT-30-HF Benchmark  \
# count                        10344          1.034400e+04
# unique                           2                   NaN
# top     Meets or Falls Below Peers                   NaN
# freq                          9533                   NaN
# mean                           NaN          9.077330e-01
# std                            NaN          7.216799e-15
# min                            NaN          9.077330e-01
# 25%                            NaN          9.077330e-01
# 50%                            NaN          9.077330e-01
# 75%                            NaN          9.077330e-01
# max                            NaN          9.077330e-01
#
#         MORT-30-HF Performance Rate  HF Normative Performance Index  \
# count                  10344.000000                    10344.000000
# unique                          NaN                             NaN
# top                             NaN                             NaN
# freq                            NaN                             NaN
# mean                       0.879884                        0.969320
# std                        0.016746                        0.018448
# min                        0.807235                        0.889287
# 25%                        0.869277                        0.957635
# 50%                        0.880347                        0.969830
# 75%                        0.890898                        0.981454
# max                        0.938040                        1.033388
#
#          HF Performance Comparison  MORT-30-PN Benchmark  \
# count                        10344          1.034400e+04
# unique                           2                   NaN
# top     Meets or Falls Below Peers                   NaN
# freq                          9926                   NaN
# mean                           NaN          8.729760e-01
# std                            NaN          6.894818e-14
# min                            NaN          8.729760e-01
# 25%                            NaN          8.729760e-01
# 50%                            NaN          8.729760e-01
# 75%                            NaN          8.729760e-01
# max                            NaN          8.729760e-01
#
#         MORT-30-PN Performance Rate  PN Normative Performance Index  \
# count                  10344.000000                    10344.000000
# unique                          NaN                             NaN
# top                             NaN                             NaN
# freq                            NaN                             NaN
# mean                       0.815171                        0.933784
# std                        0.024457                        0.028016
# min                        0.712037                        0.815643
# 25%                        0.800638                        0.917137
# 50%                        0.816225                        0.934991
# 75%                        0.830793                        0.951679
# max                        0.912152                        1.044876
#
#          PN Performance Comparison  MORT-30-COPD Benchmark  \
# count                        10344            1.034400e+04
# unique                           2                     NaN
# top     Meets or Falls Below Peers                     NaN
# freq                         10286                     NaN
# mean                           NaN            9.340020e-01
# std                            NaN            3.353036e-14
# min                            NaN            9.340020e-01
# 25%                            NaN            9.340020e-01
# 50%                            NaN            9.340020e-01
# 75%                            NaN            9.340020e-01
# max                            NaN            9.340020e-01
#
#         MORT-30-COPD Performance Rate  COPD Normative Performance Index  \
# count                    10344.000000                      10344.000000
# unique                            NaN                               NaN
# top                               NaN                               NaN
# freq                              NaN                               NaN
# mean                         0.904835                          0.968773
# std                          0.012421                          0.013298
# min                          0.841646                          0.901118
# 25%                          0.898410                          0.961893
# 50%                          0.904893                          0.968834
# 75%                          0.913125                          0.977648
# max                          0.938912                          1.005257
#
#        COPD Performance Comparison
# count                        10344
# unique                           2
# top     Meets or Falls Below Peers
# freq                         10324
# mean                           NaN
# std                            NaN
# min                            NaN
# 25%                            NaN
# 50%                            NaN
# 75%                            NaN
# max                            NaN

# %%
# Check shape of integrated dataframe

df_hrrp_hgi_hvbp_merged_copy.shape
# Out:
# (10344, 44)

# %% [markdown]
# # 07. Exporting Data

# %%
# Export cleaned Hospital Readmissions Reduction Program dataset
df_hrrp_copy.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hospital_readmissions_reduction_program_cleaned.csv'), index=False)

# %%
# Export cleaned Hospital General information dataset
df_hgi_copy.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hospital_general_information_cleaned.csv'), index=False)

# %%
# Export cleaned HVBP Clinical Outcomes datset
df_hvbp_copy.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hvbp_clinical_outcomes_cleaned.csv'), index=False)

# %%
# Export cleaned and merged HGI and HVBP Clinical Outcomes dataset
df_hgi_hvbp_merged_copy.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hgi_hvbp_merged.csv'), index=False)

# %%
# Export cleaned and integrated HRRP, HGI, and HVBP Clinical Outcomes dataset
df_hrrp_hgi_hvbp_merged_copy.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hrrp_hgi_hvbp_merged.csv'), index=False)
